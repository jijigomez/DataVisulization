# %%
import pandas as pd

# Load CSV into DataFrame
df = pd.read_csv('steals.csv')

# %%
df
# Out:
#      Unnamed: 0  GP  Games played  GS  Games started  AST  Total Assists  \
# 0             0                16                  0                 9.0
# 1             1                15                  0                 9.0
# 2             2                20                  0                11.0
# 3             3                17                  4                10.0
# 4             4                21                  6                13.0
# ..          ...               ...                ...                 ...
# 274         274                20                 20                 NaN
# 275         275                21                  0                 NaN
# 276         276                17                  2                 NaN
# 277         277                17                  0                 NaN
# 278         278                17                  6                 NaN
#
#      APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# ...

# %%
df=pd.DataFrame(df)

# %%
df.head()
# Out:
#    Unnamed: 0  GP  Games played  GS  Games started  AST  Total Assists  \
# 0           0                16                  0                 9.0
# 1           1                15                  0                 9.0
# 2           2                20                  0                11.0
# 3           3                17                  4                10.0
# 4           4                21                  6                13.0
#
#    APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# 0                    0.6           14.0                       0.9
# 1                    0.6           11.0                       0.7
# 2                    0.6           19.0                       1.0
# 3                    0.6            4.0                       0.2
# 4                    0.6           12.0                       0.6
#
#    A/TO  Assists Per Turnover  STL  Total Steals  SPG  Steals Per Game  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'GP  Games played', 'GS  Games started',
#        'AST  Total Assists', 'APG  Assists Per Game', 'TO  Turnovers',
#        'TOPG  Turnovers Per Game', 'A/TO  Assists Per Turnover',
#        'STL  Total Steals', 'SPG  Steals Per Game', 'Player', 'Position',
#        'Team'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Unnamed: 0': 'Index',
    'GP Games played': 'GP',
    'GS Games started': 'GS',
    'AST Total Assists': 'AST',
    'APG Assists Per Game': 'APG',
    'TO Turnovers': 'TO',
    'TOPG Turnovers Per Game': 'TOPG',
    'A/TO Assists Per Turnover': 'A_TO',
    'STL Total Steals': 'STL',
    'SPG Steals Per Game': 'SPG',
    'Player': 'Player',
    'Position': 'Position',
    'Team': 'Team'
})

# %%
df
# Out:
#      Index  GP  Games played  GS  Games started  AST  Total Assists  \
# 0        0                16                  0                 9.0
# 1        1                15                  0                 9.0
# 2        2                20                  0                11.0
# 3        3                17                  4                10.0
# 4        4                21                  6                13.0
# ..     ...               ...                ...                 ...
# 274    274                20                 20                 NaN
# 275    275                21                  0                 NaN
# 276    276                17                  2                 NaN
# 277    277                17                  0                 NaN
# 278    278                17                  6                 NaN
#
#      APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# 0                      0.6           14.0                       0.9
# ...

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#      Index  GP  Games played  GS  Games started  AST  Total Assists  \
# 0        0                16                  0                 9.0
# 1        1                15                  0                 9.0
# 2        2                20                  0                11.0
# 3        3                17                  4                10.0
# 4        4                21                  6                13.0
# ..     ...               ...                ...                 ...
# 274    274                20                 20                 0.0
# 275    275                21                  0                 0.0
# 276    276                17                  2                 0.0
# 277    277                17                  0                 0.0
# 278    278                17                  6                 0.0
#
#      APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# 0                      0.6           14.0                       0.9
# ...

# %%
df.to_csv('preprocessed_basketball_stats.csv', index=False)

# %%
df
# Out:
#      Index  GP  Games played  GS  Games started  AST  Total Assists  \
# 0        0                16                  0                 9.0
# 1        1                15                  0                 9.0
# 2        2                20                  0                11.0
# 3        3                17                  4                10.0
# 4        4                21                  6                13.0
# ..     ...               ...                ...                 ...
# 274    274                20                 20                 0.0
# 275    275                21                  0                 0.0
# 276    276                17                  2                 0.0
# 277    277                17                  0                 0.0
# 278    278                17                  6                 0.0
#
#      APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# 0                      0.6           14.0                       0.9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Index                       279 non-null    int64
#  1   GP  Games played            279 non-null    int64
#  2   GS  Games started           279 non-null    int64
#  3   AST  Total Assists          279 non-null    float64
#  4   APG  Assists Per Game       279 non-null    float64
#  5   TO  Turnovers               279 non-null    float64
#  6   TOPG  Turnovers Per Game    279 non-null    float64
#  7   A/TO  Assists Per Turnover  279 non-null    float64
#  8   STL  Total Steals           279 non-null    float64
#  9   SPG  Steals Per Game        279 non-null    float64
#  10  Player                      279 non-null    object
#  11  Position                    279 non-null    object
#  12  Team                        279 non-null    object
# ...

# %%
df.describe()
# Out:
#             Index  GP  Games played  GS  Games started  AST  Total Assists  \
# count  279.000000        279.000000         279.000000          279.000000
# mean   139.000000         18.530466          10.039427            0.842294
# std     80.684571          2.195066           8.439494            2.595694
# min      0.000000         14.000000           0.000000            0.000000
# 25%     69.500000         17.000000           1.000000            0.000000
# 50%    139.000000         19.000000          10.000000            0.000000
# 75%    208.500000         20.000000          19.000000            0.000000
# max    278.000000         23.000000          23.000000           13.000000
#
#        APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# count             279.000000     279.000000                279.000000
# mean                0.050179       1.136201                  0.067384
# std                 0.152644       3.686854                  0.216356
# ...

# %%
df.isnull().sum()
# Out:
# Index                         0
# GP  Games played              0
# GS  Games started             0
# AST  Total Assists            0
# APG  Assists Per Game         0
# TO  Turnovers                 0
# TOPG  Turnovers Per Game      0
# A/TO  Assists Per Turnover    0
# STL  Total Steals             0
# SPG  Steals Per Game          0
# Player                        0
# Position                      0
# Team                          0
# dtype: int64

# %%
avg_APG = df['APG  Assists Per Game'].mean()#calculate average assistants
print(f'Average APG: {avg_APG}')
# Out:
# Average APG: 0.05017921146953405

# %%
# Filter players who have started at least 10 games
df_filtered = df[df['GS  Games started'] >= 10]

# %%
df_filtered
# Out:
#      Index  GP  Games played  GS  Games started  AST  Total Assists  \
# 15      15                17                 13                 9.0
# 29      29                20                 20                 0.0
# 30      30                19                 12                 0.0
# 31      31                21                 21                 0.0
# 32      32                19                 19                 0.0
# ..     ...               ...                ...                 ...
# 258    258                20                 20                 0.0
# 259    259                21                 16                 0.0
# 269    269                19                 19                 0.0
# 273    273                20                 20                 0.0
# 274    274                20                 20                 0.0
#
#      APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# 15                     0.5           12.0                       0.7
# ...

# %%
# Sort by total assists (AST) in descending order
df_sorted = df.sort_values(by='AST  Total Assists', ascending=False)

# %%
df_sorted
# Out:
#      Index  GP  Games played  GS  Games started  AST  Total Assists  \
# 4        4                21                  6                13.0
# 2        2                20                  0                11.0
# 9        9                20                  0                11.0
# 14      14                21                  4                11.0
# 17      17                20                  5                10.0
# ..     ...               ...                ...                 ...
# 115    115                20                 20                 0.0
# 116    116                18                  1                 0.0
# 117    117                18                  0                 0.0
# 118    118                18                  4                 0.0
# 278    278                17                  6                 0.0
#
#      APG  Assists Per Game  TO  Turnovers  TOPG  Turnovers Per Game  \
# 4                      0.6           12.0                       0.6
# ...

# %%
# Group by team and calculate average assists per game
avg_APG_by_team = df.groupby('Team')['APG  Assists Per Game'].mean()
print(avg_APG_by_team)
# Out:
# Team
# ATL    0.000000
# BKN    0.000000
# BOS    0.037500
# CHA    0.000000
# CHI    0.045455
# CLE    0.111111
# DAL    0.072727
# DEN    0.060000
# DET    0.120000
# GS     0.060000
# HOU    0.083333
# IND    0.036364
# LAC    0.000000
# LAL    0.000000
# MEM    0.060000
# MIA    0.000000
# MIL    0.108333
# MIN    0.060000
# NO     0.000000
# NY     0.050000
# OKC    0.000000
# ORL    0.000000
# PHI    0.133333
# PHO    0.040000
# POR    0.062500
# SA     0.000000
# SAC    0.000000
# TOR    0.122222
# UTA    0.000000
# WAS    0.100000
# Name: APG  Assists Per Game, dtype: float64

# %%
import matplotlib.pyplot as plt

avg_APG_by_team.plot(kind='bar', figsize=(10, 6))
plt.title('Average Assists Per Game by Team')
plt.xlabel('Team')
plt.ylabel('Average APG')
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting bar charts
plt.figure(figsize=(16, 12))

# Plot 1: Games Played (GP Games played)
plt.subplot(2, 2, 1)
plt.bar(df['Player'], df['GP  Games played'], color='blue')
plt.xlabel('Player')
plt.ylabel('Games Played')
plt.title('Games Played by Player')

# Plot 2: Assists Per Game (APG Assists Per Game)
plt.subplot(2, 2, 2)
plt.bar(df['Player'], df['APG  Assists Per Game'], color='green')
plt.xlabel('Player')
plt.ylabel('Assists Per Game')
plt.title('Assists Per Game by Player')

# Plot 3: Turnovers Per Game (TOPG Turnovers Per Game)
plt.subplot(2, 2, 3)
plt.bar(df['Player'], df['TOPG  Turnovers Per Game'], color='orange')
plt.xlabel('Player')
plt.ylabel('Turnovers Per Game')
plt.title('Turnovers Per Game by Player')

# Plot 4: Steals Per Game (SPG Steals Per Game)
plt.subplot(2, 2, 4)
plt.bar(df['Player'], df['SPG  Steals Per Game'], color='red')
plt.xlabel('Player')
plt.ylabel('Steals Per Game')
plt.title('Steals Per Game by Player')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.scatter(df['GP  Games played'], df['APG  Assists Per Game'], color='blue', alpha=0.5)
plt.xlabel('Games Played')
plt.ylabel('Assists Per Game')
plt.title('Scatter Plot: Games Played vs Assists Per Game')

plt.show()

# %%
plt.figure(figsize=(8, 6))

position_counts = df['Position'].value_counts()
plt.pie(position_counts, labels=position_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart: Distribution of Positions')

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.hist(df['TOPG  Turnovers Per Game'], bins=10, color='orange', edgecolor='black')
plt.xlabel('Turnovers Per Game')
plt.ylabel('Frequency')
plt.title('Histogram: Turnovers Per Game')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(df['Player'], df['SPG  Steals Per Game'], marker='o', linestyle='-', color='green')
plt.xlabel('Player')
plt.ylabel('Steals Per Game')
plt.title('Line Plot: Steals Per Game by Player')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.tight_layout()
plt.show()
